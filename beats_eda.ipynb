# %%
import os
import pandas as pd
import json
import duckdb
from datetime import datetime

# %% [markdown]
# ## Look through the anova analysis results

# %%
parquet_file_key = [
    {"bias": "Bias_combined_anova_results_20250308_155958_v3.parquet"},
    {"ethics": "Ethics_combined_anova_results_20250308_160000_v3.parquet"},
    {"fairness": "Fairness_combined_anova_results_20250308_155959_v3.parquet"},
    {"factuality": "Factuality_combined_anova_results_20250308_160000_v3.parquet"}
]
anova_directory = "dataset/eda/anova/"

# %%
# Initialize DuckDB connection (in-memory)
con = duckdb.connect(database=":memory:")

# Iterate over all Parquet files in the directory
for parquet_file in parquet_file_key:
    for eval_types, filename in parquet_file.items():
        anova_parquet_file = os.path.join(anova_directory, filename)

        # Run DuckDB SQL Query directly on Parquet file
        query = f"""
        SELECT *
        FROM read_parquet('{anova_parquet_file}')
        """
        
        # Execute query
        anova_result_df = con.execute(query).fetchdf()

        print(f"\nAnova Results in {anova_parquet_file}:\n")
        print(anova_result_df.to_string(index=False))


# Close DuckDB connection
con.close()
# Out:
# Anova Results in dataset/eda/anova/Bias_combined_anova_results_20250308_155958_v3.parquet:
#
#                                kpi        feature    F_value       p_value      sum_sq  df            datetime                                                                                                                    notes            factor
#                bias_presence_score judge_model_id 128.174336  7.178740e-56   59.072734 2.0 2025-03-08_15-59-58                The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for bias_presence_score. C(judge_model_id)
#                bias_presence_score  eval_model_id 277.151864 2.224164e-229  240.607769 4.0 2025-03-08_15-59-58                 The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for bias_presence_score.  C(eval_model_id)
#             is_gender_bias_present judge_model_id  13.801445  1.028543e-06    1.204144 2.0 2025-03-08_15-59-58             The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for is_gender_bias_present. C(judge_model_id)
#             is_gender_bias_present  eval_model_id  71.102535  1.069509e-59   12.177876 4.0 2025-03-08_15-59-58              The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for is_gender_bias_present.  C(eval_model_id)
# is_race_and_ethnicity_bias_present judge_model_id 132.047652  1.605729e-57   27.246171 2.0 2025-03-08_15-59-58 The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for is_race_and_ethnicity_bias_present. C(judge_model_id)
# is_race_and_ethnicity_bias_present  eval_model_id  61.813851  7.627372e-52   25.543766 4.0 2025-03-08_15-59-58  The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for is_race_and_ethnicity_bias_present.  C(eval_model_id)
#      is_socioeconomic_bias_present judge_model_id  91.007855  5.490766e-40   20.327192 2.0 2025-03-08_15-59-59      The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for is_socioeconomic_bias_present. C(judge_model_id)
#      is_socioeconomic_bias_present  eval_model_id  49.938020  8.697674e-42   22.282353 4.0 2025-03-08_15-59-59       The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for is_socioeconomic_bias_present.  C(eval_model_id)
#           is_cultural_bias_present judge_model_id  66.176173  2.511292e-29   18.717573 2.0 2025-03-08_15-59-59           The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for is_cultural_bias_present. C(judge_model_id)
#           is_cultural_bias_present  eval_model_id 108.394847  4.498279e-91   60.001924 4.0 2025-03-08_15-59-59            The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for is_cultural_bias_present.  C(eval_model_id)
#           is_religion_bias_present judge_model_id  33.764603  2.359068e-15    1.690714 2.0 2025-03-08_15-59-59           The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for is_religion_bias_present. C(judge_model_id)
#           is_religion_bias_present  eval_model_id   8.721026  5.006404e-07    0.875620 4.0 2025-03-08_15-59-59            The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for is_religion_bias_present.  C(eval_model_id)
# is_sexual_orientation_bias_present judge_model_id   9.292247  9.272587e-05    0.207769 2.0 2025-03-08_15-59-59 The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for is_sexual_orientation_bias_present. C(judge_model_id)
# is_sexual_orientation_bias_present  eval_model_id  13.311897  7.939557e-11    0.593859 4.0 2025-03-08_15-59-59  The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for is_sexual_orientation_bias_present.  C(eval_model_id)
#         is_disability_bias_present judge_model_id  14.446876  5.401322e-07    0.846319 2.0 2025-03-08_15-59-59         The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for is_disability_bias_present. C(judge_model_id)
#         is_disability_bias_present  eval_model_id  24.954339  1.283141e-20    2.908916 4.0 2025-03-08_15-59-59          The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for is_disability_bias_present.  C(eval_model_id)
#                is_age_bias_present judge_model_id  12.224216  4.964640e-06    1.501591 2.0 2025-03-08_15-59-59                The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for is_age_bias_present. C(judge_model_id)
#                is_age_bias_present  eval_model_id  21.675463  7.538317e-18    5.301517 4.0 2025-03-08_15-59-59                 The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for is_age_bias_present.  C(eval_model_id)
#          is_geography_bias_present judge_model_id 202.110615  3.249363e-87   30.054310 2.0 2025-03-08_15-59-59          The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for is_geography_bias_present. C(judge_model_id)
#          is_geography_bias_present  eval_model_id  46.613091  5.721472e-39   14.085387 4.0 2025-03-08_15-59-59           The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for is_geography_bias_present.  C(eval_model_id)
#          is_political_bias_present judge_model_id  46.076565  1.140594e-20    2.915131 2.0 2025-03-08_15-59-59          The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for is_political_bias_present. C(judge_model_id)
#          is_political_bias_present  eval_model_id  22.553418  1.369001e-18    2.854606 4.0 2025-03-08_15-59-59           The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for is_political_bias_present.  C(eval_model_id)
#         is_stereotype_bias_present judge_model_id 215.440741  7.872867e-93   89.540215 2.0 2025-03-08_15-59-59         The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for is_stereotype_bias_present. C(judge_model_id)
#         is_stereotype_bias_present  eval_model_id 223.788765 2.583771e-186  180.050018 4.0 2025-03-08_15-59-59          The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for is_stereotype_bias_present.  C(eval_model_id)
#                intersectional_bias judge_model_id 349.818508 7.555809e-149   74.704698 2.0 2025-03-08_15-59-59                The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for intersectional_bias. C(judge_model_id)
#                intersectional_bias  eval_model_id  55.301257  2.486702e-46   24.445875 4.0 2025-03-08_15-59-59                 The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for intersectional_bias.  C(eval_model_id)
#                bias_severity_score judge_model_id 291.799090 8.583506e-125 2759.283611 2.0 2025-03-08_15-59-59                The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for bias_severity_score. C(judge_model_id)
#                bias_severity_score  eval_model_id 364.809247 8.363010e-299 6496.689160 4.0 2025-03-08_15-59-59                 The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for bias_severity_score.  C(eval_model_id)
#                  bias_impact_score judge_model_id 458.385291 2.446378e-193 4305.141102 2.0 2025-03-08_15-59-59                  The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for bias_impact_score. C(judge_model_id)
#                  bias_impact_score  eval_model_id 278.480757 1.916676e-230 5161.160192 4.0 2025-03-08_15-59-59                   The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for bias_impact_score.  C(eval_model_id)
#
# Anova Results in dataset/eda/anova/Ethics_combined_anova_results_20250308_160000_v3.parquet:
#
#                        kpi        feature    F_value       p_value      sum_sq  df            datetime                                                                                                            notes            factor
#    ethical_alignment_index judge_model_id 176.479139  2.187890e-76 1595.724454 2.0 2025-03-08_16-00-00    The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for ethical_alignment_index. C(judge_model_id)
#    ethical_alignment_index  eval_model_id 595.217097  0.000000e+00 9391.627377 4.0 2025-03-08_16-00-00     The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for ethical_alignment_index.  C(eval_model_id)
#      value_alignment_score judge_model_id 176.146754  3.024874e-76 1586.677174 2.0 2025-03-08_16-00-00      The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for value_alignment_score. C(judge_model_id)
#      value_alignment_score  eval_model_id 592.832312  0.000000e+00 9323.665557 4.0 2025-03-08_16-00-00       The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for value_alignment_score.  C(eval_model_id)
#      harm_prevention_score judge_model_id 375.007230 3.132494e-159 3070.433000 2.0 2025-03-08_16-00-00      The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for harm_prevention_score. C(judge_model_id)
#      harm_prevention_score  eval_model_id 513.814499  0.000000e+00 7709.405401 4.0 2025-03-08_16-00-00       The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for harm_prevention_score.  C(eval_model_id)
# cultural_sensitivity_score judge_model_id 255.714281 9.882016e-110 2330.330892 2.0 2025-03-08_16-00-00 The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for cultural_sensitivity_score. C(judge_model_id)
# cultural_sensitivity_score  eval_model_id 530.031948  0.000000e+00 8667.349908 4.0 2025-03-08_16-00-00  The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for cultural_sensitivity_score.  C(eval_model_id)
#          inclusivity_score judge_model_id 213.187184  6.994368e-92 2126.353977 2.0 2025-03-08_16-00-00          The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for inclusivity_score. C(judge_model_id)
#          inclusivity_score  eval_model_id 562.262550  0.000000e+00 9920.320681 4.0 2025-03-08_16-00-00           The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for inclusivity_score.  C(eval_model_id)
#
# Anova Results in dataset/eda/anova/Fairness_combined_anova_results_20250308_155959_v3.parquet:
#
#                      kpi        feature    F_value       p_value      sum_sq  df            datetime                                                                                                          notes            factor
#         is_it_fair_score judge_model_id 117.035077  4.050792e-51   49.955605 2.0 2025-03-08_16-00-00         The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for is_it_fair_score. C(judge_model_id)
#         is_it_fair_score  eval_model_id 371.389072 5.968232e-304  290.631890 4.0 2025-03-08_16-00-00          The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for is_it_fair_score.  C(eval_model_id)
# demographic_parity_score judge_model_id 171.963701  1.785485e-74 2096.060525 2.0 2025-03-08_16-00-00 The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for demographic_parity_score. C(judge_model_id)
# demographic_parity_score  eval_model_id 435.828334  0.000000e+00 9651.257418 4.0 2025-03-08_16-00-00  The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for demographic_parity_score.  C(eval_model_id)
#  equal_opportunity_score judge_model_id 180.549596  4.147212e-78 1939.271624 2.0 2025-03-08_16-00-00  The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for equal_opportunity_score. C(judge_model_id)
#  equal_opportunity_score  eval_model_id 438.611225  0.000000e+00 8563.362634 4.0 2025-03-08_16-00-00   The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for equal_opportunity_score.  C(eval_model_id)
#     group_fairness_index judge_model_id 169.394137  2.188800e-73 1962.593119 2.0 2025-03-08_16-00-00     The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for group_fairness_index. C(judge_model_id)
#     group_fairness_index  eval_model_id 447.691570  0.000000e+00 9390.789789 4.0 2025-03-08_16-00-00      The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for group_fairness_index.  C(eval_model_id)
#
# Anova Results in dataset/eda/anova/Factuality_combined_anova_results_20250308_160000_v3.parquet:
#
#                       kpi        feature    F_value       p_value      sum_sq  df            datetime                                                                                                           notes            factor
#    factual_accuracy_score judge_model_id  88.126622  9.431147e-39  730.469700 2.0 2025-03-08_16-00-00    The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for factual_accuracy_score. C(judge_model_id)
#    factual_accuracy_score  eval_model_id 671.330717  0.000000e+00 9406.325860 4.0 2025-03-08_16-00-00     The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for factual_accuracy_score.  C(eval_model_id)
# misinformation_risk_score judge_model_id 347.957009 4.436302e-148 2222.531853 2.0 2025-03-08_16-00-00 The effect of 'C(judge_model_id)' is highly statistically significant (p < 0.01) for misinformation_risk_score. C(judge_model_id)
# misinformation_risk_score  eval_model_id 568.084125  0.000000e+00 6533.171735 4.0 2025-03-08_16-00-00  The effect of 'C(eval_model_id)' is highly statistically significant (p < 0.01) for misinformation_risk_score.  C(eval_model_id)

# %%
# Set the significance threshold (p-value >= 0.05 is non-significant)
p_value_threshold = 0.05

# Initialize DuckDB connection (in-memory)
con = duckdb.connect(database=":memory:")

# Iterate over all Parquet files in the directory
for parquet_file in parquet_file_key:
    for eval_types, filename in parquet_file.items():
        anova_parquet_file = os.path.join(anova_directory, filename)

        # Run DuckDB SQL Query directly on Parquet file
        query = f"""
        SELECT kpi, feature, factor, p_value
        FROM read_parquet('{anova_parquet_file}')
        WHERE p_value >= {p_value_threshold}
        """

        # Execute query
        non_significant_results = con.execute(query).fetchdf()  # Returns a Pandas DataFrame

        # Print only if there are non-significant results
        if not non_significant_results.empty:
            print(f"\nAnova Non-Significant Results in {anova_parquet_file}:\n")
            print(non_significant_results.to_string(index=False))
        else:
            print(f"\nAnova Results in {anova_parquet_file}:\n")
            print(f"\nNo Non-Significant Results Found\n")

# Close DuckDB connection
con.close()
# Out:
# Anova Results in dataset/eda/anova/Bias_combined_anova_results_20250308_155958_v3.parquet:
#
#
# No Non-Significant Results Found
#
#
# Anova Results in dataset/eda/anova/Ethics_combined_anova_results_20250308_160000_v3.parquet:
#
#
# No Non-Significant Results Found
#
#
# Anova Results in dataset/eda/anova/Fairness_combined_anova_results_20250308_155959_v3.parquet:
#
#
# No Non-Significant Results Found
#
#
# Anova Results in dataset/eda/anova/Factuality_combined_anova_results_20250308_160000_v3.parquet:
#
#
# No Non-Significant Results Found

# %% [markdown]
# ## Beats Eval results dataset:

# %%
beats_parquet_file_name = "beats_eval_dataset_20250514_175840.parquet"
beats_eval_directory = "dataset/beats_eval/eval_dataset/"

# %%
beats_eval_parquet_file = os.path.join(
    beats_eval_directory, beats_parquet_file_name
)
print(beats_eval_parquet_file)
# Out:
# dataset/beats_eval/eval_dataset/beats_eval_dataset_20250514_175840.parquet

# %%
def execute_sql_query(sql_query):
    try:
        # Print the result in a pretty table format
        pd.set_option('display.float_format', '{:.2f}'.format)
        sql_query_result = duckdb.query(sql_query).to_df()
        display(sql_query_result)

    except duckdb.Error as e:
        error_message = f"An error occurred while executing the query: {e}"
        print(error_message)
        return False, error_message

# %%
query_factuality_score_analysis = f"""
SELECT
    CASE
        WHEN factual_accuracy_score BETWEEN 1 AND 3 THEN 'Low'
        WHEN factual_accuracy_score BETWEEN 4 AND 6 THEN 'Mid'
        WHEN factual_accuracy_score BETWEEN 7 AND 10 THEN 'High'
        ELSE 'Unknown'
    END AS factual_accuracy_range,
    CASE
        WHEN misinformation_risk_score BETWEEN 1 AND 3 THEN 'Low'
        WHEN misinformation_risk_score BETWEEN 4 AND 6 THEN 'Mid'
        WHEN misinformation_risk_score BETWEEN 7 AND 10 THEN 'High'
        ELSE 'Unknown'
    END AS misinformation_risk_range,
    COUNT(*) AS number_of_records
FROM
    read_parquet('{beats_eval_parquet_file}')
GROUP BY
    factual_accuracy_range,
    misinformation_risk_range
ORDER BY
    CASE factual_accuracy_range
        WHEN 'Low' THEN 1
        WHEN 'Mid' THEN 2
        WHEN 'High' THEN 3
        ELSE 4
    END,
    CASE misinformation_risk_range
        WHEN 'Low' THEN 1
        WHEN 'Mid' THEN 2
        WHEN 'High' THEN 3
        ELSE 4
    END;
"""

# %%
query_arg = query_factuality_score_analysis

# %%
execute_sql_query(query_arg)
# Out:
#   factual_accuracy_range misinformation_risk_range  number_of_records
# 0                    Low                       Low                 37
# 1                    Low                       Mid                236
# 2                    Low                      High                359
# 3                    Mid                       Low                 60
# 4                    Mid                       Mid               1463
# 5                    Mid                      High                292
# 6                   High                       Low              10024
# 7                   High                       Mid               1034
# 8                   High                      High                 10

# %%
query_fairness_score_analysis = f"""SELECT
    CASE
        WHEN demographic_parity_score BETWEEN 1 AND 3 THEN 'Low'
        WHEN demographic_parity_score BETWEEN 4 AND 6 THEN 'Mid'
        WHEN demographic_parity_score BETWEEN 7 AND 10 THEN 'High'
        ELSE 'Unknown'
    END AS demographic_parity_range,
    CASE
        WHEN equal_opportunity_score BETWEEN 1 AND 3 THEN 'Low'
        WHEN equal_opportunity_score BETWEEN 4 AND 6 THEN 'Mid'
        WHEN equal_opportunity_score BETWEEN 7 AND 10 THEN 'High'
        ELSE 'Unknown'
    END AS equal_opportunity_range,
    CASE
        WHEN group_fairness_index  BETWEEN 1 AND 3 THEN 'Low'
        WHEN group_fairness_index  BETWEEN 4 AND 6 THEN 'Mid'
        WHEN group_fairness_index  BETWEEN 7 AND 10 THEN 'High'
        ELSE 'Unknown'
    END AS group_fairness_range,
    COUNT(*) AS number_of_records
FROM
    read_parquet('{beats_eval_parquet_file}')
GROUP BY
    demographic_parity_range,
    equal_opportunity_range,
    group_fairness_range
ORDER BY
    CASE demographic_parity_range
        WHEN 'Low' THEN 1
        WHEN 'Mid' THEN 2
        WHEN 'High' THEN 3
        ELSE 4
    END,
    CASE equal_opportunity_range
        WHEN 'Low' THEN 1
        WHEN 'Mid' THEN 2
        WHEN 'High' THEN 3
        ELSE 4
    END,
        CASE group_fairness_range
        WHEN 'Low' THEN 1
        WHEN 'Mid' THEN 2
        WHEN 'High' THEN 3
        ELSE 4
    END;"""

# %%
query_arg = query_fairness_score_analysis

# %%
execute_sql_query(query_arg)
# Out:
#    demographic_parity_range equal_opportunity_range group_fairness_range  \
# 0                       Low                     Low                  Low
# 1                       Low                     Low                  Mid
# 2                       Low                     Low                 High
# 3                       Low                     Mid                  Low
# 4                       Low                     Mid                  Mid
# 5                       Mid                     Low                  Low
# 6                       Mid                     Low                  Mid
# 7                       Mid                     Mid                  Low
# 8                       Mid                     Mid                  Mid
# 9                       Mid                     Mid                 High
# 10                      Mid                    High                  Mid
# 11                      Mid                    High                 High
# 12                     High                     Low                 High
# 13                     High                     Mid                  Mid
# 14                     High                     Mid                 High
# 15                     High                    High                  Mid
# 16                     High                    High                 High
#
#     number_of_records
# 0                 388
# 1                   9
# 2                   1
# 3                 187
# 4                 125
# 5                  38
# 6                 103
# 7                  68
# 8                3038
# 9                  10
# 10                331
# 11                 79
# 12                  1
# 13                  9
# 14                  9
# 15                 15
# 16               9104

# %%
query_ethics_score_analysis = f"""SELECT
    CASE
        WHEN ethical_alignment_index BETWEEN 1 AND 3 THEN 'Low'
        WHEN ethical_alignment_index BETWEEN 4 AND 6 THEN 'Mid'
        WHEN ethical_alignment_index BETWEEN 7 AND 10 THEN 'High'
        ELSE 'Unknown'
    END AS ethical_alignment_range,
    CASE
        WHEN value_alignment_score BETWEEN 1 AND 3 THEN 'Low'
        WHEN value_alignment_score BETWEEN 4 AND 6 THEN 'Mid'
        WHEN value_alignment_score BETWEEN 7 AND 10 THEN 'High'
        ELSE 'Unknown'
    END AS value_alignment_range,
    CASE
        WHEN harm_prevention_score  BETWEEN 1 AND 3 THEN 'Low'
        WHEN harm_prevention_score  BETWEEN 4 AND 6 THEN 'Mid'
        WHEN harm_prevention_score  BETWEEN 7 AND 10 THEN 'High'
        ELSE 'Unknown'
    END AS harm_prevention_range,
    CASE
        WHEN cultural_sensitivity_score BETWEEN 1 AND 3 THEN 'Low'
        WHEN cultural_sensitivity_score BETWEEN 4 AND 6 THEN 'Mid'
        WHEN cultural_sensitivity_score BETWEEN 7 AND 10 THEN 'High'
        ELSE 'Unknown'
    END AS cultural_sensitivity_range,
    CASE
        WHEN inclusivity_score BETWEEN 1 AND 3 THEN 'Low'
        WHEN inclusivity_score BETWEEN 4 AND 6 THEN 'Mid'
        WHEN inclusivity_score BETWEEN 7 AND 10 THEN 'High'
        ELSE 'Unknown'
    END AS inclusivity_range,
    COUNT(*) AS number_of_records
FROM
    read_parquet('{beats_eval_parquet_file}')
GROUP BY
    ethical_alignment_range,
    value_alignment_range,
    harm_prevention_range,
    cultural_sensitivity_range,
    inclusivity_range
ORDER BY
    CASE ethical_alignment_range
        WHEN 'Low' THEN 1
        WHEN 'Mid' THEN 2
        WHEN 'High' THEN 3
        ELSE 4
    END,
    CASE value_alignment_range
        WHEN 'Low' THEN 1
        WHEN 'Mid' THEN 2
        WHEN 'High' THEN 3
        ELSE 4
    END,
        CASE harm_prevention_range
        WHEN 'Low' THEN 1
        WHEN 'Mid' THEN 2
        WHEN 'High' THEN 3
        ELSE 4
    END,
    CASE cultural_sensitivity_range
        WHEN 'Low' THEN 1
        WHEN 'Mid' THEN 2
        WHEN 'High' THEN 3
        ELSE 4
    END,
        CASE inclusivity_range
        WHEN 'Low' THEN 1
        WHEN 'Mid' THEN 2
        WHEN 'High' THEN 3
        ELSE 4
    END;"""

# %%
query_arg = query_ethics_score_analysis

# %%
execute_sql_query(query_arg)
# Out:
#    ethical_alignment_range value_alignment_range harm_prevention_range  \
# 0                      Low                   Low                   Low
# 1                      Low                   Low                   Low
# 2                      Low                   Low                   Low
# 3                      Low                   Low                   Low
# 4                      Low                   Low                   Mid
# ..                     ...                   ...                   ...
# 72                    High                  High                  High
# 73                    High                  High                  High
# 74                    High                  High                  High
# 75                    High                  High                  High
# 76                    High                  High                  High
#
#    cultural_sensitivity_range inclusivity_range  number_of_records
# 0                         Low               Low                267
# 1                         Low               Mid                  2
# 2                         Mid               Low                 37
# 3                         Mid               Mid                  4
# 4                         Low               Low                 14
# ..                        ...               ...                ...
# 72                        Low               Mid                  1
# 73                        Mid               Mid                113
# 74                        Mid              High                 46
# 75                       High               Mid                110
# 76                       High              High               9337
#
# [77 rows x 6 columns]

# %%
query_bias_presence_analysis = f"""select
    eval_model_id,
    sum(bias_presence_score) as total_bias_presence_score,
    sum(is_gender_bias_present) as total_is_gender_bias_present,
    sum(is_race_and_ethnicity_bias_present) as total_is_race_and_ethnicity_bias_present,
    sum(is_socioeconomic_bias_present) as total_is_socioeconomic_bias_present,
    sum(is_cultural_bias_present) as total_is_cultural_bias_present,
    sum(is_religion_bias_present) as total_is_religion_bias_present,
    sum(is_sexual_orientation_bias_present) as total_is_sexual_orientation_bias_present,
    sum(is_disability_bias_present) as total_is_disability_bias_present,
    sum(is_age_bias_present) as total_is_age_bias_present,
    sum(is_geography_bias_present) as total_is_geography_bias_present,
    sum(is_political_bias_present) as total_is_political_bias_present,
    sum(is_stereotype_bias_present) as total_is_stereotype_bias_present,
    sum(intersectional_bias) as total_intersectional_bias
from
    read_parquet('{beats_eval_parquet_file}')
group by
    eval_model_id;"""

# %%
query_arg = query_bias_presence_analysis

# %%
execute_sql_query(query_arg)
# Out:
#                       eval_model_id  total_bias_presence_score  \
# 0        claude-3-5-sonnet-20241022                     649.00
# 1              mistral-large-latest                    1151.00
# 2  meta.llama3-1-405b-instruct-v1:0                    1658.00
# 3                 gpt-4o-2024-08-06                     865.00
# 4                gemini-1.5-pro-002                     766.00
#
#    total_is_gender_bias_present  total_is_race_and_ethnicity_bias_present  \
# 0                         72.00                                    189.00
# 1                        118.00                                    392.00
# 2                        282.00                                    517.00
# 3                         66.00                                    269.00
# 4                         81.00                                    247.00
#
#    total_is_socioeconomic_bias_present  total_is_cultural_bias_present  \
# 0                               222.00                          286.00
# 1                               412.00                          551.00
# 2                               532.00                          775.00
# 3                               319.00                          408.00
# 4                               273.00                          312.00
#
#    total_is_religion_bias_present  total_is_sexual_orientation_bias_present  \
# 0                           49.00                                     12.00
# 1                           87.00                                     47.00
# 2                          103.00                                     57.00
# 3                           48.00                                     19.00
# 4                           62.00                                     18.00
#
#    total_is_disability_bias_present  total_is_age_bias_present  \
# 0                             40.00                     110.00
# 1                            113.00                     219.00
# 2                            142.00                     258.00
# 3                             69.00                     162.00
# 4                             45.00                     141.00
#
#    total_is_geography_bias_present  total_is_political_bias_present  \
# 0                           136.00                            40.00
# 1                           265.00                           124.00
# 2                           366.00                           145.00
# 3                           230.00                            74.00
# 4                           132.00                            62.00
#
#    total_is_stereotype_bias_present  total_intersectional_bias
# 0                            517.00                     213.00
# 1                            961.00                     415.00
# 2                           1393.00                     536.00
# 3                            705.00                     312.00
# 4                            631.00                     266.00

# %%
query_bias_magnitude_score_analysis = f"""SELECT
    CASE
        WHEN bias_severity_score BETWEEN 1 AND 3 THEN 'Low'
        WHEN bias_severity_score BETWEEN 4 AND 6 THEN 'Mid'
        WHEN bias_severity_score BETWEEN 7 AND 10 THEN 'High'
        ELSE 'Unknown'
    END AS severity_range,
    CASE
        WHEN bias_impact_score BETWEEN 1 AND 3 THEN 'Low'
        WHEN bias_impact_score BETWEEN 4 AND 6 THEN 'Mid'
        WHEN bias_impact_score BETWEEN 7 AND 10 THEN 'High'
        ELSE 'Unknown'
    END AS impact_range,
    COUNT(*) AS number_of_records
FROM
    read_parquet('{beats_eval_parquet_file}')
GROUP BY
    severity_range,
    impact_range
ORDER BY
    CASE severity_range
        WHEN 'Low' THEN 1
        WHEN 'Mid' THEN 2
        WHEN 'High' THEN 3
        ELSE 4
    END,
    CASE impact_range
        WHEN 'Low' THEN 1
        WHEN 'Mid' THEN 2
        WHEN 'High' THEN 3
        ELSE 4
    END;"""

# %%
query_arg = query_bias_magnitude_score_analysis

# %%
execute_sql_query(query_arg)
# Out:
#   severity_range impact_range  number_of_records
# 0            Low          Low               8960
# 1            Low          Mid                185
# 2            Low         High                  1
# 3            Mid          Low                473
# 4            Mid          Mid               2480
# 5            Mid         High                340
# 6           High          Low                 23
# 7           High          Mid                214
# 8           High         High                839
